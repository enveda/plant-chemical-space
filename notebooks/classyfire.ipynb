# %% [markdown]
# # Classify chemicals using ClassyFire
#
# ### Import modules

# %%
from collections import defaultdict
import time
import json
from pandas import json_normalize
from ast import literal_eval

from pybatchclassyfire import *
import pandas as pd
from tqdm import tqdm

from rdkit import RDLogger  
from rdkit.Chem.inchi import MolToInchi, InchiToInchiKey
from rdkit.Chem import MolFromSmiles
# Out:
# /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# INFO:rdkit:Enabling RDKit 2022.09.1 jupyter extensions

# %%
RDLogger.DisableLog('rdApp.*')

# %%
DATA_DIR = '../data/'

# %% [markdown]
# Load plant-chemical associations

# %%
plant_chemical_df = pd.read_csv(
    f'{DATA_DIR}/plant_chemical_associations.tsv.zip',
    compression='zip',
    sep='\t',
    usecols=[
        'plant_curie',
        'chemical_curie',
    ]
)

# %%
plant_chemical_df.head(1)
# Out:
#          plant_curie         chemical_curie
# 0  ncbitaxon:1000425  pubchem.compound:3527

# %%
len(plant_chemical_df.chemical_curie.unique())
# Out:
# 71179

# %% [markdown]
# Get SMILES

# %%
smiles_df = pd.read_csv(
    f'{DATA_DIR}/smiles.tsv.gz',
    sep='\t',
    compression='gzip',
)

# %%
smiles_df.head(1)
# Out:
#      pubchem id                                             smiles
# 0  pubchem:3527  CC(=CCCC1(C(CC2(C(=O)C(=C(C3=CC(=C(C=C3)O)O)O)...

# %%
pubchem_to_smiles = {}
all_smiles = set()

chemicals_in_plants = set(plant_chemical_df.chemical_curie.unique())

for pubchem_id, smiles in tqdm(smiles_df.values):
        
    if pubchem_id.startswith('pubchem:'):
        pubchem_id = pubchem_id.replace('pubchem:', 'pubchem.compound:')
        
    if pubchem_id not in chemicals_in_plants:
        continue
    
    all_smiles.add(smiles)
    pubchem_to_smiles[pubchem_id] = smiles

smiles_to_pubchem = {
    smiles: pubchem
    for pubchem, smiles in pubchem_to_smiles.items()
}
# Out:
# 100%|██████████| 323369/323369 [00:00<00:00, 495993.42it/s]

# %%
len(all_smiles)
# Out:
# 69954

# %%
all_inchikeys = set()
skipped = 0

for smiles in tqdm(all_smiles):
    try:
        mol = MolFromSmiles(smiles)
    except:
        skipped += 1
    
    all_inchikeys.add(InchiToInchiKey(MolToInchi(mol)))
# Out:
# 100%|██████████| 69954/69954 [00:39<00:00, 1793.24it/s]

# %%
skipped
# Out:
# 0

# %%
np_classifier_df = pd.read_parquet(
    's3://enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet'
)
# Out:
# DEBUG:botocore.hooks:Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# DEBUG:botocore.hooks:Changing event name from before-call.apigateway to before-call.api-gateway
# DEBUG:botocore.hooks:Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# DEBUG:botocore.hooks:Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# DEBUG:botocore.hooks:Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# DEBUG:botocore.hooks:Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# DEBUG:botocore.hooks:Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# DEBUG:s3fs:Setting up s3fs instance
# DEBUG:botocore.utils:IMDS ENDPOINT: http://169.254.169.254/
# DEBUG:botocore.credentials:Looking for credentials via: env
# DEBUG:botocore.credentials:Looking for credentials via: assume-role
# DEBUG:botocore.credentials:Looking for credentials via: assume-role-with-web-identity
# DEBUG:botocore.credentials:Looking for credentials via: sso
# DEBUG:botocore.credentials:Looking for credentials via: shared-credentials-file
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# DEBUG:botocore.loaders:Loading JSON file: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/botocore/data/endpoints.json
# DEBUG:botocore.hooks:Event choose-service-name: calling handler <function handle_service_name_alias at 0x7fc878c2c790>
# DEBUG:botocore.loaders:Loading JSON file: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/botocore/data/s3/2006-03-01/service-2.json
# DEBUG:botocore.hooks:Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x7fc848974a60>
# DEBUG:botocore.hooks:Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x7fc848974820>
# DEBUG:botocore.endpoint:Setting s3 timeout as (5, 15)
# DEBUG:botocore.loaders:Loading JSON file: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/botocore/data/_retry.json
# DEBUG:botocore.client:Registering retry handlers for service: s3
# DEBUG:s3fs:CALL: head_object - ({},) - {'Bucket': 'enveda-data-kg', 'Key': 'kg3/raw_source_downloads/manual_uploads/np_classifier.parquet'}
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=HeadObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.HeadObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Defaulting to S3 virtual host style addressing with path style addressing fallback.
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# HEAD
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120203Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120203Z
# 20230208/us-east-1/s3/aws4_request
# 6c4171728715ce18788292d5c7b95bd83bc9252d56d4014422b1b40bbee9fea3
# DEBUG:botocore.auth:Signature:
# 15a50a3b3080a3a5ee0c8f98a4320072f173840f3c57809238eab7f7caba6c5e
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120203Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=15a50a3b3080a3a5ee0c8f98a4320072f173840f3c57809238eab7f7caba6c5e'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): enveda-data-kg.s3.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "HEAD /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 200 0
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'MyyW91vsz5sUbzzT69ZenSmyUvs12pC2fLjBjUnATFHrX06L7Bo9S2WtqJhKTHo+h3QL54HTq64=', 'x-amz-request-id': 'AXS0X7N392PBBBH2', 'Date': 'Wed, 08 Feb 2023 12:02:04 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '18577952'}
# DEBUG:botocore.parsers:Response body:
# b''
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:s3fs:CALL: head_object - ({},) - {'Bucket': 'enveda-data-kg', 'Key': 'kg3/raw_source_downloads/manual_uploads/np_classifier.parquet'}
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=HeadObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.HeadObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# HEAD
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120203Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120203Z
# 20230208/us-east-1/s3/aws4_request
# 6c4171728715ce18788292d5c7b95bd83bc9252d56d4014422b1b40bbee9fea3
# DEBUG:botocore.auth:Signature:
# 15a50a3b3080a3a5ee0c8f98a4320072f173840f3c57809238eab7f7caba6c5e
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120203Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=15a50a3b3080a3a5ee0c8f98a4320072f173840f3c57809238eab7f7caba6c5e'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "HEAD /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 200 0
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'zjtX+SDzYV13yB0avR2HqxoiwVdXH9pJojsu9J2YwV4vdcqOMDrv8TNq7inpeHCfyNzoeSuT53k=', 'x-amz-request-id': 'AXS76AJWZ4BZP9QM', 'Date': 'Wed, 08 Feb 2023 12:02:04 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '18577952'}
# DEBUG:botocore.parsers:Response body:
# b''
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:s3fs:CALL: head_object - ({},) - {'Bucket': 'enveda-data-kg', 'Key': 'kg3/raw_source_downloads/manual_uploads/np_classifier.parquet'}
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=HeadObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.HeadObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# HEAD
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120203Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120203Z
# 20230208/us-east-1/s3/aws4_request
# 6c4171728715ce18788292d5c7b95bd83bc9252d56d4014422b1b40bbee9fea3
# DEBUG:botocore.auth:Signature:
# 15a50a3b3080a3a5ee0c8f98a4320072f173840f3c57809238eab7f7caba6c5e
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120203Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=15a50a3b3080a3a5ee0c8f98a4320072f173840f3c57809238eab7f7caba6c5e'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "HEAD /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 200 0
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'DJQgb3FATIylb0JFDDtFisbspDI1JfM12Wt9yh/GDoI84n7eUIqGCyQHsP2zDH+jyZm0yfNMXTE=', 'x-amz-request-id': 'AXS0QP1ENKM4TTHG', 'Date': 'Wed, 08 Feb 2023 12:02:04 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '18577952'}
# DEBUG:botocore.parsers:Response body:
# b''
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:fsspec:<File-like object S3FileSystem, enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet> read: 18512416 - 18577952
# DEBUG:s3fs:Fetch: enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, 18512416-18577952
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=GetObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'GET', 'headers': {'Range': 'bytes=18512416-18577951', 'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.GetObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# GET
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# range:bytes=18512416-18577951
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120204Z
#
# host;range;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120204Z
# 20230208/us-east-1/s3/aws4_request
# a306160bb70509a7c3194d1f48d352de9da93e6f9f4173e6e801a1f53b50d1b3
# DEBUG:botocore.auth:Signature:
# 47026a682c8dd468bfa79c5bfaf170906e153278c38085682726e08ee7ac4022
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'Range': b'bytes=18512416-18577951', 'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120204Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;range;x-amz-content-sha256;x-amz-date, Signature=47026a682c8dd468bfa79c5bfaf170906e153278c38085682726e08ee7ac4022'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "GET /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 206 65536
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'P3IfWXzOPPSyl538OQRGnCC76OsZQYBvMass9VWSFKsSfDwewrELcFren8nIhphdTS4f9u49xrE=', 'x-amz-request-id': '6X6XQZ2R5KXQ258S', 'Date': 'Wed, 08 Feb 2023 12:02:05 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Range': 'bytes 18512416-18577951/18577952', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '65536'}
# DEBUG:botocore.parsers:Response body:
# <botocore.response.StreamingBody object at 0x7fc869951dc0>
# DEBUG:botocore.hooks:Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:s3fs:CALL: head_object - ({},) - {'Bucket': 'enveda-data-kg', 'Key': 'kg3/raw_source_downloads/manual_uploads/np_classifier.parquet'}
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=HeadObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.HeadObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# HEAD
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120204Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120204Z
# 20230208/us-east-1/s3/aws4_request
# 2016669c81c1b58b98aedb4918a59f7204af5b9240cab508361dde20175076e0
# DEBUG:botocore.auth:Signature:
# f8adb46bed1c3d819537fd332a877fb601654f1d31abaeeb187598b7cc273c5c
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120204Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=f8adb46bed1c3d819537fd332a877fb601654f1d31abaeeb187598b7cc273c5c'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "HEAD /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 200 0
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'hV5J8FeMe20Zk6FxT02nnjID0Z5mG9Q+87NEVrB60iRP3Um7/nkMoBIQJQlWdmV/AULna1dtGCU=', 'x-amz-request-id': '6X6NWW1N4YRR3WFQ', 'Date': 'Wed, 08 Feb 2023 12:02:05 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '18577952'}
# DEBUG:botocore.parsers:Response body:
# b''
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:s3fs:CALL: head_object - ({},) - {'Bucket': 'enveda-data-kg', 'Key': 'kg3/raw_source_downloads/manual_uploads/np_classifier.parquet'}
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=HeadObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.HeadObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# HEAD
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120204Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120204Z
# 20230208/us-east-1/s3/aws4_request
# 2016669c81c1b58b98aedb4918a59f7204af5b9240cab508361dde20175076e0
# DEBUG:botocore.auth:Signature:
# f8adb46bed1c3d819537fd332a877fb601654f1d31abaeeb187598b7cc273c5c
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120204Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=f8adb46bed1c3d819537fd332a877fb601654f1d31abaeeb187598b7cc273c5c'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "HEAD /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 200 0
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'M0LAjFpKR6e6vya8EggZ2rcC/Y+vTli8BOExA+IfgKixgT6gni8NDlrSJvmHYhfdjeXb5ThGgi0=', 'x-amz-request-id': '6X6WH8AYE1PESBTB', 'Date': 'Wed, 08 Feb 2023 12:02:05 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '18577952'}
# DEBUG:botocore.parsers:Response body:
# b''
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:fsspec:<File-like object S3FileSystem, enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet> read: 18512416 - 18577952
# DEBUG:s3fs:Fetch: enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, 18512416-18577952
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=GetObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'GET', 'headers': {'Range': 'bytes=18512416-18577951', 'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.GetObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# GET
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# range:bytes=18512416-18577951
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120204Z
#
# host;range;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120204Z
# 20230208/us-east-1/s3/aws4_request
# a306160bb70509a7c3194d1f48d352de9da93e6f9f4173e6e801a1f53b50d1b3
# DEBUG:botocore.auth:Signature:
# 47026a682c8dd468bfa79c5bfaf170906e153278c38085682726e08ee7ac4022
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'Range': b'bytes=18512416-18577951', 'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120204Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;range;x-amz-content-sha256;x-amz-date, Signature=47026a682c8dd468bfa79c5bfaf170906e153278c38085682726e08ee7ac4022'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "GET /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 206 65536
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'LMrWqiljF+y/gJ0yDOdr7s7ncPI4StBQjndz7a6TW/3Db7R95YaiD0aswLvGiEr4hsoigmkgIBA=', 'x-amz-request-id': '6X6WEHY7AMGMJVJ2', 'Date': 'Wed, 08 Feb 2023 12:02:05 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Range': 'bytes 18512416-18577951/18577952', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '65536'}
# DEBUG:botocore.parsers:Response body:
# <botocore.response.StreamingBody object at 0x7fc86996a100>
# DEBUG:botocore.hooks:Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:fsspec:<File-like object S3FileSystem, enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet> read: 4 - 18573274
# DEBUG:s3fs:Fetch: enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, 4-18512416
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fc878c4b040>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fc878c47f70>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <bound method S3ArnParamHandler.handle_arn of <botocore.utils.S3ArnParamHandler object at 0x7fc8596c3f70>>
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fc878c47dc0>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fc878c4b310>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>
# DEBUG:botocore.hooks:Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x7fc878c4d670>
# DEBUG:botocore.endpoint:Making request for OperationModel(name=GetObject) with params: {'url_path': '/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'query_string': {}, 'method': 'GET', 'headers': {'Range': 'bytes=4-18512415', 'User-Agent': 'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0'}, 'body': b'', 'url': 'https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7fc8596c3460>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'enveda-data-kg'}}}
# DEBUG:botocore.hooks:Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fc8596c3310>>
# DEBUG:botocore.hooks:Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7fc85963afd0>>
# DEBUG:botocore.hooks:Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fc878c47ca0>
# DEBUG:botocore.hooks:Event before-sign.s3.GetObject: calling handler <bound method S3EndpointSetter.set_endpoint of <botocore.utils.S3EndpointSetter object at 0x7fc848d24040>>
# DEBUG:botocore.utils:Checking for DNS compatible bucket for: https://s3.amazonaws.com/enveda-data-kg/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.utils:URI updated to: https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# GET
# /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet
#
# host:enveda-data-kg.s3.amazonaws.com
# range:bytes=4-18512415
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20230208T120205Z
#
# host;range;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20230208T120205Z
# 20230208/us-east-1/s3/aws4_request
# b89dd481f3d2fb18694e4caccbd82cf2cfec4aac760bc99ea804e250eac338b0
# DEBUG:botocore.auth:Signature:
# 985507a9aa691a2fd50e5a3b4b4567df2f35aaa81506cf5d28e5d5e143f83915
# DEBUG:botocore.endpoint:Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://enveda-data-kg.s3.amazonaws.com/kg3/raw_source_downloads/manual_uploads/np_classifier.parquet, headers={'Range': b'bytes=4-18512415', 'User-Agent': b'Botocore/1.20.49 Python/3.8.3 Darwin/22.3.0', 'X-Amz-Date': b'20230208T120205Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAUSMJNHVQKJDLWTMG/20230208/us-east-1/s3/aws4_request, SignedHeaders=host;range;x-amz-content-sha256;x-amz-date, Signature=985507a9aa691a2fd50e5a3b4b4567df2f35aaa81506cf5d28e5d5e143f83915'}>
# DEBUG:botocore.httpsession:Certificate path: /Users/danieldomingo/anaconda3/lib/python3.8/site-packages/certifi/cacert.pem
# DEBUG:urllib3.connectionpool:https://enveda-data-kg.s3.amazonaws.com:443 "GET /kg3/raw_source_downloads/manual_uploads/np_classifier.parquet HTTP/1.1" 206 18512412
# DEBUG:botocore.parsers:Response headers: {'x-amz-id-2': 'nKkDBY4/h5NFYq5U52lepG63f+W0MyhPSyNbN3nfZM0XYLXv0bpK8vlFr5gyqz3jx8FnJTGj3e0=', 'x-amz-request-id': 'JM8F5CW7QQCFACM4', 'Date': 'Wed, 08 Feb 2023 12:02:06 GMT', 'Last-Modified': 'Thu, 04 Aug 2022 14:34:31 GMT', 'ETag': '"d757e507c9216000655975ba6c11b753-4"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'cRWywcR84nL0HBtqnqAy4CCpYhfViHTd', 'Accept-Ranges': 'bytes', 'Content-Range': 'bytes 4-18512415/18577952', 'Content-Type': 'binary/octet-stream', 'Server': 'AmazonS3', 'Content-Length': '18512412'}
# DEBUG:botocore.parsers:Response body:
# <botocore.response.StreamingBody object at 0x7fc86996a4c0>
# DEBUG:botocore.hooks:Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fc8596c3e50>
# DEBUG:botocore.retryhandler:No retry needed.
# DEBUG:botocore.hooks:Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fc8596c3eb0>>

# %%
np_classifier_df.head(5)
# Out:
#    Unnamed: 0 pubchem_openeye_can_smiles  \
# 2           2   C1=CC(C(C(=C1)C(=O)O)O)O
# 3           3                    CC(CN)O
# 4           4       C(C(=O)COP(=O)(O)O)N
# 6           6     CCN1C=NC2=C(N=CN=C21)N
# 7           7        CCC(C)(C(C(=O)O)O)O
#
#                                        class_results  \
# 2  ['Shikimic acids and derivatives', 'Simple phe...
# 3                                                 []
# 4                                     ['Aminoacids']
# 6                               ['Purine alkaloids']
# 7                            ['Hydroxy fatty acids']
#
#                superclass_results  \
# 2      ['Phenolic acids (C6-C1)']
# 3                              []
# 4              ['Small peptides']
# 6             ['Pseudoalkaloids']
# 7  ['Fatty Acids and Conjugates']
#
#                                      pathway_results  is_glycoside
# 2                ['Shikimates and Phenylpropanoids']         False
# 3                                                 []         False
# 4  ['Amino acids and Peptides', 'Shikimates and P...         False
# 6                                      ['Alkaloids']         False
# 7                                    ['Fatty acids']         False

# %%
smiles_to_np_classifier = {}

all_classes = set()
all_superclasses = set()
all_pathways = set()

for _, smiles, classes, superclasses, pathways, is_glycoside in np_classifier_df.values:
    
    if smiles not in smiles_to_pubchem:
        continue
        
    for clas in literal_eval(classes):
        all_classes.add(clas)
        
    for clas in literal_eval(superclasses):
        all_superclasses.add(clas)
        
    for clas in literal_eval(pathways):
        all_pathways.add(clas)
        
    smiles_to_np_classifier[smiles_to_pubchem[smiles]] = {
        "classes": literal_eval(classes),
        "superclasses": literal_eval(superclasses),
        "pathways": literal_eval(pathways),
        "is_glycoside": is_glycoside,
    }

# %%
len(all_classes), len(all_superclasses), len(all_pathways)
# Out:
# (524, 71, 7)

# %% [markdown]
# Ping API

# %%
resolved_ik_number_list = [0, 0]
total_inchi_number = len(all_inchikeys)

while True:
    
    start_time = time.time()
    
    print('%s inchikey to resolve' % total_inchi_number )
    get_classifications_cf_mod(all_inchikeys, par_level= 50)
    
    cleanse('all_json.json', 'all_json.json')
    
    with open("all_json.json") as tweetfile:
        jsondic = json.loads(tweetfile.read())

    df = json_normalize(jsondic)
    df = df.drop_duplicates('smiles')
    resolved_ik_number = len( df.drop_duplicates('smiles').inchikey )
    resolved_ik_number_list.append( resolved_ik_number )
    print('%s resolved smiles' % resolved_ik_number )
    print("done in --- %s seconds ---" % (time.time() - start_time))
    
    if resolved_ik_number_list[-1] < resolved_ik_number_list[-2] or resolved_ik_number_list[-1] == resolved_ik_number_list[-3]:
        break
# Out:
# 69891 inchikey to resolve
# 64321 resolved smiles
# done in --- 473.6717128753662 seconds ---
# 69891 inchikey to resolve
# 64321 resolved smiles
# done in --- 147.92391800880432 seconds ---
# 69891 inchikey to resolve
# 64321 resolved smiles
# done in --- 135.92525792121887 seconds ---

# %%
df.head()
# Out:
#                                               smiles  \
# 0  [H]C1(C)CCC2(CCC3(C)C(=CCC4([H])C5(C)CCC([H])(...
# 1  C[C@@]1(CC[C@@]2(C)[C@@H](CC[C@@]3(C)[C@@H]2C=...
# 2  COC1=C(OC)C2=C(C=C1)C(=O)C1=C(O)C(C3C(OC4=C3C3...
# 3  CC(=O)OCC12C(CC(C)(O)C3(CC(OC3=O)c3ccoc3)C1(O)...
# 4  COC(=O)[C@H](C\C=C\C(C)(C)O)[C@@H]1[C@@H](O)C[...
#
#                                inchikey  \
# 0  InChIKey=RRIMLWHUVCZACL-UHFFFAOYSA-N
# 1  InChIKey=CVAILKMOFONEDU-KRJMWWHISA-N
# 2  InChIKey=BDURUBOYNAVRCF-UHFFFAOYSA-N
# 3  InChIKey=PLNVNTKQZPPADC-UHFFFAOYSA-N
# 4  InChIKey=KTEXQEFLIOIDKM-GEMWEJHDSA-N
#
#                                   intermediate_nodes  \
# 0  [{'name': 'Triterpene glycosides', 'descriptio...
# 1                                                 []
# 2  [{'name': 'Acridines', 'description': 'Organic...
# 3                                                 []
# 4                                                 []
#
#                                  alternative_parents  \
# 0  [{'name': 'Triterpenoids', 'description': 'Ter...
# 1  [{'name': 'Sesquiterpenoids', 'description': '...
# 2  [{'name': 'Hydroquinolones', 'description': 'C...
# 3  [{'name': 'Gamma butyrolactones', 'description...
# 4  [{'name': 'Cholesterols and derivatives', 'des...
#
#                     molecular_framework  \
# 0  Aliphatic heteropolycyclic compounds
# 1    Aliphatic homopolycyclic compounds
# 2   Aromatic heteropolycyclic compounds
# 3   Aromatic heteropolycyclic compounds
# 4    Aliphatic homopolycyclic compounds
#
#                                         substituents  \
# 0  [Triterpene saponin, Triterpenoid, Hexose mono...
# 1  [18-oxosteroid, Oxosteroid, Sesquiterpenoid, H...
# 2  [Acridone, Dihydroquinolone, Dihydroquinoline,...
# 3  [Tricarboxylic acid or derivatives, Gamma buty...
# 4  [Triterpenoid, Cholesterol-skeleton, Cholestan...
#
#                                          description external_descriptors  \
# 0  This compound belongs to the class of organic ...                   []
# 1  This compound belongs to the class of organic ...                   []
# 2  This compound belongs to the class of organic ...                   []
# 3  This compound belongs to the class of organic ...                   []
# 4  This compound belongs to the class of organic ...                   []
#
#                                            ancestors  \
# 0  [Acetals, Alcohols and polyols, Carbohydrates ...
# 1  [Benzenoids, Carbonyl compounds, Carboxylic ac...
# 2  [1-hydroxy-2-unsubstituted benzenoids, 1-hydro...
# 3  [Alcohols and polyols, Carbonyl compounds, Car...
# 4  [16-beta-hydroxysteroids, 16-hydroxysteroids, ...
#
#                                predicted_chebi_terms  ...  \
# 0  [triterpenoid (CHEBI:36615), hexose (CHEBI:181...  ...
# 1  [sesquiterpenoid (CHEBI:26658), phenanthrenes ...  ...
# 2  [quinolines (CHEBI:26513), 1-benzofurans (CHEB...  ...
# 3  [gamma-lactone (CHEBI:37581), oxolanes (CHEBI:...  ...
# 4  [cholestanoid (CHEBI:50401), cholanoid (CHEBI:...  ...
#
#                          subclass.name  \
# 0                   Terpene glycosides
# 1                          Oxosteroids
# 2                      Benzoquinolines
# 3  Tricarboxylic acids and derivatives
# 4                        Triterpenoids
#
#                                 subclass.description subclass.chemont_id  \
# 0  Prenol lipids containing a carbohydrate moiety...   CHEMONTID:0002049
# 1  Steroid derivatives carrying a C=O group attac...   CHEMONTID:0001194
# 2  Organic compounds containing a benzene fused t...   CHEMONTID:0001908
# 3  Carboxylic acids containing exactly three carb...   CHEMONTID:0001986
# 4   Terpene molecules containing six isoprene units.   CHEMONTID:0001553
#
#                                         subclass.url  \
# 0  http://classyfire.wishartlab.com/tax_nodes/C00...
# 1  http://classyfire.wishartlab.com/tax_nodes/C00...
# 2  http://classyfire.wishartlab.com/tax_nodes/C00...
# 3  http://classyfire.wishartlab.com/tax_nodes/C00...
# 4  http://classyfire.wishartlab.com/tax_nodes/C00...
#
#                     direct_parent.name  \
# 0                  Triterpene saponins
# 1                          Oxosteroids
# 2                            Acridones
# 3  Tricarboxylic acids and derivatives
# 4                        Triterpenoids
#
#                            direct_parent.description direct_parent.chemont_id  \
# 0  Glycosylated derivatives of triterpene sapogen...        CHEMONTID:0002358
# 1  Steroid derivatives carrying a C=O group attac...        CHEMONTID:0001194
# 2  Acridines containing a ketone group attached t...        CHEMONTID:0001811
# 3  Carboxylic acids containing exactly three carb...        CHEMONTID:0001986
# 4   Terpene molecules containing six isoprene units.        CHEMONTID:0001553
#
#                                    direct_parent.url identifier report
# 0  http://classyfire.wishartlab.com/tax_nodes/C00...        NaN    NaN
# 1  http://classyfire.wishartlab.com/tax_nodes/C00...        NaN    NaN
# 2  http://classyfire.wishartlab.com/tax_nodes/C00...        NaN    NaN
# 3  http://classyfire.wishartlab.com/tax_nodes/C00...        NaN    NaN
# 4  http://classyfire.wishartlab.com/tax_nodes/C00...        NaN    NaN
#
# [5 rows x 34 columns]

# %%
df.to_csv('classyfire_smiles.tsv.gz', sep='\t', compression='gzip')

# %%
np_classifier_df.to_csv('npclassifier_smiles.tsv.gz', sep='\t', compression='gzip')
